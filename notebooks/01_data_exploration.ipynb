# %% [markdown]
# # ECG Data Exploration
#
# This notebook performs exploratory data analysis on the ECG dataset.
#
# ## Objectives:
# - Load and inspect ECG data
# - Visualize signal characteristics
# - Analyze patient demographics and disease distribution
# - Identify data quality issues

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
# df = pd.read_csv('../datasets/ecg_data.csv')
